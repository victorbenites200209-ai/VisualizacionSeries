# %%
entrada = "10,15,18,26,31,"
entrada
# Out:
# '10,15,18,26,31,'

# %%
entrada2 = entrada.split(",")

# %%
entrada2
# Out:
# ['10', '15', '18', '26', '31', '']

# %%
[float(i) for i in entrada2]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 [float(i) for i in entrada2]
#
# ValueError: could not convert string to float: ''
